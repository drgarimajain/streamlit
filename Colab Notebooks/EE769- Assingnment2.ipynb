# %%
# First, you would upload the zip file to the Colab environment

# Use the unzip command in the shell to extract the contents of the zip file
# !unzip  /content/drive/MyDrive/Colab Notebooks/wine+quality.zip -d /content/drive/MyDrive/Colab Notebooks

# For example, if the uploaded zip file is named 'data.zip' and you want to extract it to 'data' folder:
#!unzip data.zip -d data/
# Out:
# unzip:  cannot find or open /content/drive/MyDrive/Colab, /content/drive/MyDrive/Colab.zip or /content/drive/MyDrive/Colab.ZIP.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# Assuming your dataset is in a CSV file named 'your_dataset.csv'
# Load the dataset into a pandas DataFrame
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/wine+quality/winequality-red.csv')

# Print the header (column names)
print(df.columns.tolist())

# Show the first 5 rows of the dataset
print(df.head())

# Code taken from  stack overfolw
# Out:
# ['fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"']
#   fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 0   7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5
# 1   7.8;0.88;0;2.6;0.098;25;67;0.9968;3.2;0.68;9.8;5
# 2  7.8;0.76;0.04;2.3;0.092;15;54;0.997;3.26;0.65;...
# 3  11.2;0.28;0.56;1.9;0.075;17;60;0.998;3.16;0.58...
# 4   7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5
